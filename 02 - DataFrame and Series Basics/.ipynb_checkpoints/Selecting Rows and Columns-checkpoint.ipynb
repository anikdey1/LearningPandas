# %%
import pandas as pd

# %%
sr_df = pd.read_csv('../Data/partial_public_survey_results.csv')
srs_df = pd.read_csv('../Data/survey_results_schema.csv')

# %%
pd.set_option('display.max_columns', 114)
pd.set_option('display.max_rows', 114)

# %%
sr_df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %%
people_dict = {
    'first_name': ['Alice', 'Bartholomew', 'Claire'],
    'last_name': ['Zane', 'Yeoman', 'Xavier'],
    'email_address': ['a_zane@email.com', 'b_yeoman@email.com', 'c_xavier@email.com']
    }

people_df = pd.DataFrame(people_dict)
people_df
# Out:
#     first_name last_name       email_address
# 0        Alice      Zane    a_zane@email.com
# 1  Bartholomew    Yeoman  b_yeoman@email.com
# 2       Claire    Xavier  c_xavier@email.com

# %%
people_df['last_name']
# Out:
# 0      Zane
# 1    Yeoman
# 2    Xavier
# Name: last_name, dtype: object

# %%
type(people_df['last_name'])
# Out:
# pandas.core.series.Series

# %%
# people_df.first_name
# Out:
# 0          Alice
# 1    Bartholomew
# 2         Claire
# Name: first_name, dtype: object

# %%
people_df[['last_name', 'email_address']]
# Out:
#   last_name       email_address
# 0      Zane    a_zane@email.com
# 1    Yeoman  b_yeoman@email.com
# 2    Xavier  c_xavier@email.com

# %%
type(people_df[['last_name', 'email_address']])
# Out:
# pandas.core.frame.DataFrame

# %%
people_df.columns
# Out:
# Index(['first_name', 'last_name', 'email_address'], dtype='object')

# %%
people_df.iloc[0]
# Out:
# first_name                  Alice
# last_name                    Zane
# email_address    a_zane@email.com
# Name: 0, dtype: object

# %%
people_df.iloc[[1, 2]]
# Out:
#     first_name last_name       email_address
# 1  Bartholomew    Yeoman  b_yeoman@email.com
# 2       Claire    Xavier  c_xavier@email.com

# %%
people_df.iloc[[1]]
# Out:
#     first_name last_name       email_address
# 1  Bartholomew    Yeoman  b_yeoman@email.com

# %%
people_df.iloc[[0, 2], [2, 1]]
# Out:
#         email_address last_name
# 0    a_zane@email.com      Zane
# 2  c_xavier@email.com    Xavier

# %%
people_df.loc[0]
# Out:
# first_name                  Alice
# last_name                    Zane
# email_address    a_zane@email.com
# Name: 0, dtype: object

# %%
people_df.loc[[0, 2]]
# Out:
#   first_name last_name       email_address
# 0      Alice      Zane    a_zane@email.com
# 2     Claire    Xavier  c_xavier@email.com

# %%
type(people_df.loc[[0, 2]])
# Out:
# pandas.core.frame.DataFrame

# %%
people_df.loc[[0, 1], ['last_name', 'first_name']]
# Out:
#   last_name   first_name
# 0      Zane        Alice
# 1    Yeoman  Bartholomew

# %%
sr_df[['Employment']].head(5)
# Out:
#             Employment
# 0  Employed, full-time
# 1  Employed, full-time
# 2  Employed, full-time
# 3   Student, full-time
# 4   Student, full-time

# %%
sr_df[['RemoteWork']].value_counts()
# Out:
# RemoteWork
# Remote                                  3602
# Hybrid (some remote, some in-person)    3447
# In-person                               1587
# Name: count, dtype: int64

# %%
sr_df.loc[[5], ['EdLevel']]
# Out:
#                      EdLevel
# 5  Primary/elementary school

# %%
sr_df.loc[[_ for _ in range(6)], ['EdLevel']]
# Out:
#                                              EdLevel
# 0                          Primary/elementary school
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3  Some college/university study without earning ...
# 4  Secondary school (e.g. American high school, G...
# 5                          Primary/elementary school

# %%
sr_df.loc[6:10, 'MainBranch':'CodingActivities']
# Out:
#                                            MainBranch              Age  \
# 6   I am not primarily a developer, but I write co...  35-44 years old
# 7                               I am learning to code  18-24 years old
# 8                         I code primarily as a hobby  45-54 years old
# 9                      I am a developer by profession  35-44 years old
# 10  I used to be a developer by profession, but no...  35-44 years old
#
#                                            Employment RemoteWork   Check  \
# 6                                 Employed, full-time     Remote  Apples
# 7   Student, full-time;Not employed, but looking f...        NaN  Apples
# 8                                 Employed, full-time  In-person  Apples
# 9   Independent contractor, freelancer, or self-em...     Remote  Apples
# 10                                Employed, full-time     Remote  Apples
#
#                             CodingActivities
# 6               I don’t code outside of work
# ...

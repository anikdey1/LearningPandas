# %%
import pandas as pd

# %%
people_dict = {
    'id': ['1001', '1002', '1003', '2001', '2002', '2003'],
    'first_name': ['Alice', 'Bartholomew', 'Claire', 'Dave', 'Emma', 'Freya'],
    'last_name': ['Zane', 'Yeoman', 'Xavier', 'Weiss', 'Vichy', 'Underwood'],
    'email_address': ['a_zane@email.com', 'b_yeoman@email.com', 'c_xavier@email.com', 'dave_w@email.com', 'emma_v@email.com', 'freya_u@email.com']
    }

people_df = pd.DataFrame(people_dict)
people_df
# Out:
#      id   first_name  last_name       email_address
# 0  1001        Alice       Zane    a_zane@email.com
# 1  1002  Bartholomew     Yeoman  b_yeoman@email.com
# 2  1003       Claire     Xavier  c_xavier@email.com
# 3  2001         Dave      Weiss    dave_w@email.com
# 4  2002         Emma      Vichy    emma_v@email.com
# 5  2003        Freya  Underwood   freya_u@email.com

# %%
people_df.sort_values('last_name', ascending=True)
# Out:
#      id   first_name  last_name       email_address
# 5  2003        Freya  Underwood   freya_u@email.com
# 4  2002         Emma      Vichy    emma_v@email.com
# 3  2001         Dave      Weiss    dave_w@email.com
# 2  1003       Claire     Xavier  c_xavier@email.com
# 1  1002  Bartholomew     Yeoman  b_yeoman@email.com
# 0  1001        Alice       Zane    a_zane@email.com

# %%
people_df.sort_values(by=['id', 'first_name'], ascending=[False, True])
# Out:
#      id   first_name  last_name       email_address
# 5  2003        Freya  Underwood   freya_u@email.com
# 4  2002         Emma      Vichy    emma_v@email.com
# 3  2001         Dave      Weiss    dave_w@email.com
# 2  1003       Claire     Xavier  c_xavier@email.com
# 1  1002  Bartholomew     Yeoman  b_yeoman@email.com
# 0  1001        Alice       Zane    a_zane@email.com

# %%
people_df.sort_index(ascending=False)
# Out:
#      id   first_name  last_name       email_address
# 5  2003        Freya  Underwood   freya_u@email.com
# 4  2002         Emma      Vichy    emma_v@email.com
# 3  2001         Dave      Weiss    dave_w@email.com
# 2  1003       Claire     Xavier  c_xavier@email.com
# 1  1002  Bartholomew     Yeoman  b_yeoman@email.com
# 0  1001        Alice       Zane    a_zane@email.com

# %%
sr_df = pd.read_csv('../Data/partial_public_survey_results.csv', index_col='ResponseId')
srs_df = pd.read_csv('../Data/survey_results_schema.csv', index_col='qname')

pd.set_option('display.max_columns', 113)
pd.set_option('display.max_rows', 87)

sr_df.head()
# Out:
#                                 MainBranch                 Age  \
# ResponseId
# 1           I am a developer by profession  Under 18 years old
# 2           I am a developer by profession     35-44 years old
# 3           I am a developer by profession     45-54 years old
# 4                    I am learning to code     18-24 years old
# 5           I am a developer by profession     18-24 years old
#
#                      Employment RemoteWork   Check  \
# ResponseId
# 1           Employed, full-time     Remote  Apples
# 2           Employed, full-time     Remote  Apples
# 3           Employed, full-time     Remote  Apples
# 4            Student, full-time        NaN  Apples
# 5            Student, full-time        NaN  Apples
#
#                                              CodingActivities  \
# ResponseId
# 1                                                       Hobby
# 2           Hobby;Contribute to open-source projects;Other...
# 3           Hobby;Contribute to open-source projects;Other...
# 4                                                         NaN
# 5                                                         NaN
#
#                                                       EdLevel  \
# ResponseId
# 1                                   Primary/elementary school
# 2                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3             Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4           Some college/university study without earning ...
# 5           Secondary school (e.g. American high school, G...
#
#                                                     LearnCode  \
# ResponseId
# 1                                      Books / Physical media
# 2           Books / Physical media;Colleague;On the job tr...
# 3           Books / Physical media;Colleague;On the job tr...
# 4           Other online resources (e.g., videos, blogs, f...
# 5           Other online resources (e.g., videos, blogs, f...
#
#                                               LearnCodeOnline  \
# ResponseId
# 1                                                         NaN
# 2           Technical documentation;Blogs;Books;Written Tu...
# 3           Technical documentation;Blogs;Books;Written Tu...
# 4           Stack Overflow;How-to videos;Interactive tutorial
# 5           Technical documentation;Blogs;Written Tutorial...
#
#                                                       TechDoc YearsCode  \
# ResponseId
# 1                                                         NaN       NaN
# 2           API document(s) and/or SDK document(s);User gu...        20
# 3           API document(s) and/or SDK document(s);User gu...        37
# 4                                                         NaN         4
# 5           API document(s) and/or SDK document(s);User gu...         9
#
#            YearsCodePro                DevType OrgSize PurchaseInfluence  \
# ResponseId
# 1                   NaN                    NaN     NaN               NaN
# 2                    17  Developer, full-stack     NaN               NaN
# 3                    27   Developer Experience     NaN               NaN
# 4                   NaN  Developer, full-stack     NaN               NaN
# 5                   NaN  Developer, full-stack     NaN               NaN
#
#            BuyNewTool BuildvsBuy TechEndorse  \
# ResponseId
# 1                 NaN        NaN         NaN
# 2                 NaN        NaN         NaN
# 3                 NaN        NaN         NaN
# 4                 NaN        NaN         NaN
# 5                 NaN        NaN         NaN
#
#                                                       Country Currency  \
# ResponseId
# 1                                    United States of America      NaN
# 2           United Kingdom of Great Britain and Northern I...      NaN
# 3           United Kingdom of Great Britain and Northern I...      NaN
# 4                                                      Canada      NaN
# 5                                                      Norway      NaN
#
#             CompTotal                             LanguageHaveWorkedWith  \
# ResponseId
# 1                 NaN                                                NaN
# 2                 NaN  Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 3                 NaN                                                 C#
# 4                 NaN  C;C++;HTML/CSS;Java;JavaScript;PHP;PowerShell;...
# 5                 NaN            C++;HTML/CSS;JavaScript;Lua;Python;Rust
#
#                                        LanguageWantToWorkWith  \
# ResponseId
# 1                                                         NaN
# 2           Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 3                                                          C#
# 4           HTML/CSS;Java;JavaScript;PowerShell;Python;SQL...
# 5                          C++;HTML/CSS;JavaScript;Lua;Python
#
#                                               LanguageAdmired  \
# ResponseId
# 1                                                         NaN
# 2           Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 3                                                          C#
# 4           HTML/CSS;Java;JavaScript;PowerShell;Python;SQL...
# 5                          C++;HTML/CSS;JavaScript;Lua;Python
#
#                      DatabaseHaveWorkedWith      DatabaseWantToWorkWith  \
# ResponseId
# 1                                       NaN                         NaN
# 2               Dynamodb;MongoDB;PostgreSQL                  PostgreSQL
# 3                Firebase Realtime Database  Firebase Realtime Database
# 4           MongoDB;MySQL;PostgreSQL;SQLite    MongoDB;MySQL;PostgreSQL
# 5                         PostgreSQL;SQLite           PostgreSQL;SQLite
#
#                        DatabaseAdmired  \
# ResponseId
# 1                                  NaN
# 2                           PostgreSQL
# 3           Firebase Realtime Database
# 4             MongoDB;MySQL;PostgreSQL
# 5                    PostgreSQL;SQLite
#
#                               PlatformHaveWorkedWith  \
# ResponseId
# 1                                                NaN
# 2           Amazon Web Services (AWS);Heroku;Netlify
# 3                                       Google Cloud
# 4            Amazon Web Services (AWS);Fly.io;Heroku
# 5                                                NaN
#
#                               PlatformWantToWorkWith  \
# ResponseId
# 1                                                NaN
# 2           Amazon Web Services (AWS);Heroku;Netlify
# 3                                       Google Cloud
# 4                   Amazon Web Services (AWS);Vercel
# 5                                                NaN
#
#                                      PlatformAdmired  \
# ResponseId
# 1                                                NaN
# 2           Amazon Web Services (AWS);Heroku;Netlify
# 3                                       Google Cloud
# 4                          Amazon Web Services (AWS)
# 5                                                NaN
#
#                             WebframeHaveWorkedWith  \
# ResponseId
# 1                                              NaN
# 2                    Express;Next.js;Node.js;React
# 3                                     ASP.NET CORE
# 4           jQuery;Next.js;Node.js;React;WordPress
# 5                                              NaN
#
#                       WebframeWantToWorkWith               WebframeAdmired  \
# ResponseId
# 1                                        NaN                           NaN
# 2           Express;Htmx;Node.js;React;Remix         Express;Node.js;React
# 3                               ASP.NET CORE                  ASP.NET CORE
# 4               jQuery;Next.js;Node.js;React  jQuery;Next.js;Node.js;React
# 5                                        NaN                           NaN
#
#              EmbeddedHaveWorkedWith EmbeddedWantToWorkWith    EmbeddedAdmired  \
# ResponseId
# 1                               NaN                    NaN                NaN
# 2                               NaN                    NaN                NaN
# 3                       Rasberry Pi            Rasberry Pi        Rasberry Pi
# 4                       Rasberry Pi                    NaN                NaN
# 5           CMake;Cargo;Rasberry Pi      CMake;Rasberry Pi  CMake;Rasberry Pi
#
#                                      MiscTechHaveWorkedWith  \
# ResponseId
# 1                                                       NaN
# 2                                                       NaN
# 3           .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# 4                              NumPy;Pandas;Ruff;TensorFlow
# 5                                                       NaN
#
#                                      MiscTechWantToWorkWith  \
# ResponseId
# 1                                                       NaN
# 2                                                       NaN
# 3           .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# 4                                                       NaN
# 5                                                       NaN
#
#                                             MiscTechAdmired  \
# ResponseId
# 1                                                       NaN
# 2                                                       NaN
# 3           .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# 4                                                       NaN
# 5                                                       NaN
#
#                                 ToolsTechHaveWorkedWith  \
# ResponseId
# 1                                                   NaN
# 2           Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 3                                               MSBuild
# 4                                        Docker;npm;Pip
# 5                                          APT;Make;npm
#
#                                 ToolsTechWantToWorkWith  \
# ResponseId
# 1                                                   NaN
# 2           Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 3                                               MSBuild
# 4                                 Docker;Kubernetes;npm
# 5                                              APT;Make
#
#                                        ToolsTechAdmired  \
# ResponseId
# 1                                                   NaN
# 2           Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 3                                               MSBuild
# 4                                            Docker;npm
# 5                                              APT;Make
#
#                    NEWCollabToolsHaveWorkedWith  \
# ResponseId
# 1                                           NaN
# 2           PyCharm;Visual Studio Code;WebStorm
# 3                                 Visual Studio
# 4                                           NaN
# 5                                           Vim
#
#                    NEWCollabToolsWantToWorkWith  \
# ResponseId
# 1                                           NaN
# 2           PyCharm;Visual Studio Code;WebStorm
# 3                                 Visual Studio
# 4                                           NaN
# 5                                           Vim
#
#                           NEWCollabToolsAdmired        OpSysPersonal use  \
# ResponseId
# 1                                           NaN                      NaN
# 2           PyCharm;Visual Studio Code;WebStorm            MacOS;Windows
# 3                                 Visual Studio                  Windows
# 4                                           NaN                      NaN
# 5                                           Vim  Other (please specify):
#
#            OpSysProfessional use  \
# ResponseId
# 1                            NaN
# 2                          MacOS
# 3                        Windows
# 4                            NaN
# 5                            NaN
#
#                                OfficeStackAsyncHaveWorkedWith  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4                                                         NaN
# 5           GitHub Discussions;Markdown File;Obsidian;Stac...
#
#                        OfficeStackAsyncWantToWorkWith  \
# ResponseId
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5           GitHub Discussions;Markdown File;Obsidian
#
#                               OfficeStackAsyncAdmired  \
# ResponseId
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5           GitHub Discussions;Markdown File;Obsidian
#
#                            OfficeStackSyncHaveWorkedWith  \
# ResponseId
# 1                                                    NaN
# 2                                  Microsoft Teams;Slack
# 3           Google Chat;Google Meet;Microsoft Teams;Zoom
# 4                                                    NaN
# 5                                       Discord;Whatsapp
#
#            OfficeStackSyncWantToWorkWith        OfficeStackSyncAdmired  \
# ResponseId
# 1                                    NaN                           NaN
# 2                                  Slack                         Slack
# 3           Google Chat;Google Meet;Zoom  Google Chat;Google Meet;Zoom
# 4                                    NaN                           NaN
# 5                       Discord;Whatsapp              Discord;Whatsapp
#
#            AISearchDevHaveWorkedWith AISearchDevWantToWorkWith  \
# ResponseId
# 1                                NaN                       NaN
# 2                                NaN                       NaN
# 3                                NaN                       NaN
# 4                                NaN                       NaN
# 5                                NaN                       NaN
#
#            AISearchDevAdmired  \
# ResponseId
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5                         NaN
#
#                                                    NEWSOSites  \
# ResponseId
# 1           I have never visited Stack Overflow or the Sta...
# 2           Stack Overflow for Teams (private knowledge sh...
# 3           Stack Overflow;Stack Exchange;Stack Overflow B...
# 4                                              Stack Overflow
# 5           Stack Overflow for Teams (private knowledge sh...
#
#                        SOVisitFreq SOAccount              SOPartFreq  \
# ResponseId
# 1                              NaN       NaN                     NaN
# 2           Multiple times per day       Yes  Multiple times per day
# 3           Multiple times per day       Yes  Multiple times per day
# 4            Daily or almost daily        No                     NaN
# 5           Multiple times per day       Yes  Multiple times per day
#
#                                                         SOHow  \
# ResponseId
# 1                                                         NaN
# 2           Quickly finding code solutions;Finding reliabl...
# 3           Quickly finding code solutions;Finding reliabl...
# 4                              Quickly finding code solutions
# 5           Quickly finding code solutions;Engage with com...
#
#                      SOComm                 AISelect          AISent  \
# ResponseId
# 1                       NaN                      Yes  Very favorable
# 2           Yes, definitely  No, and I don't plan to             NaN
# 3           Yes, definitely  No, and I don't plan to             NaN
# 4            No, not really                      Yes  Very favorable
# 5           Yes, definitely  No, and I don't plan to             NaN
#
#                                                         AIBen           AIAcc  \
# ResponseId
# 1                                       Increase productivity             NaN
# 2                                                         NaN             NaN
# 3                                                         NaN             NaN
# 4           Increase productivity;Greater efficiency;Impro...  Somewhat trust
# 5                                                         NaN             NaN
#
#                                 AIComplex  \
# ResponseId
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4           Bad at handling complex tasks
# 5                                     NaN
#
#                                         AIToolCurrently Using  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4           Learning about a codebase;Project planning;Wri...
# 5                                                         NaN
#
#                                     AIToolInterested in Using  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4           Testing code;Committing and reviewing code;Pre...
# 5                                                         NaN
#
#            AIToolNot interested in Using  \
# ResponseId
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
#
#                                    AINextMuch more integrated AINextNo change  \
# ResponseId
# 1                                                         NaN             NaN
# 2                                                         NaN             NaN
# 3                                                         NaN             NaN
# 4           Learning about a codebase;Project planning;Wri...             NaN
# 5                                                         NaN             NaN
#
#            AINextMore integrated AINextLess integrated  \
# ResponseId
# 1                            NaN                   NaN
# 2                            NaN                   NaN
# 3                            NaN                   NaN
# 4                            NaN                   NaN
# 5                            NaN                   NaN
#
#            AINextMuch less integrated AIThreat  \
# ResponseId
# 1                                 NaN      NaN
# 2                                 NaN      NaN
# 3                                 NaN      NaN
# 4                                 NaN       No
# 5                                 NaN      NaN
#
#                                                      AIEthics  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4           Circulating misinformation or disinformation;M...
# 5                                                         NaN
#
#                                  AIChallenges TBranch                  ICorPM  \
# ResponseId
# 1                                         NaN      No                     NaN
# 2                                         NaN     Yes  Individual contributor
# 3                                         NaN      No                     NaN
# 4           Don’t trust the output or answers     NaN                     NaN
# 5                                         NaN     NaN                     NaN
#
#             WorkExp Knowledge_1 Knowledge_2 Knowledge_3 Knowledge_4  \
# ResponseId
# 1               NaN         NaN         NaN         NaN         NaN
# 2              17.0       Agree    Disagree       Agree       Agree
# 3               NaN         NaN         NaN         NaN         NaN
# 4               NaN         NaN         NaN         NaN         NaN
# 5               NaN         NaN         NaN         NaN         NaN
#
#            Knowledge_5                 Knowledge_6 Knowledge_7 Knowledge_8  \
# ResponseId
# 1                  NaN                         NaN         NaN         NaN
# 2                Agree  Neither agree nor disagree    Disagree       Agree
# 3                  NaN                         NaN         NaN         NaN
# 4                  NaN                         NaN         NaN         NaN
# 5                  NaN                         NaN         NaN         NaN
#
#            Knowledge_9 Frequency_1 Frequency_2 Frequency_3 TimeSearching  \
# ResponseId
# 1                  NaN         NaN         NaN         NaN           NaN
# 2                Agree         NaN         NaN         NaN           NaN
# 3                  NaN         NaN         NaN         NaN           NaN
# 4                  NaN         NaN         NaN         NaN           NaN
# 5                  NaN         NaN         NaN         NaN           NaN
#
#            TimeAnswering Frustration ProfessionalTech ProfessionalCloud  \
# ResponseId
# 1                    NaN         NaN              NaN               NaN
# 2                    NaN         NaN              NaN               NaN
# 3                    NaN         NaN              NaN               NaN
# 4                    NaN         NaN              NaN               NaN
# 5                    NaN         NaN              NaN               NaN
#
#            ProfessionalQuestion Industry  JobSatPoints_1  JobSatPoints_4  \
# ResponseId
# 1                           NaN      NaN             NaN             NaN
# 2                           NaN      NaN             0.0             0.0
# 3                           NaN      NaN             NaN             NaN
# 4                           NaN      NaN             NaN             NaN
# 5                           NaN      NaN             NaN             NaN
#
#             JobSatPoints_5  JobSatPoints_6  JobSatPoints_7  JobSatPoints_8  \
# ResponseId
# 1                      NaN             NaN             NaN             NaN
# 2                      0.0             0.0             0.0             0.0
# 3                      NaN             NaN             NaN             NaN
# 4                      NaN             NaN             NaN             NaN
# 5                      NaN             NaN             NaN             NaN
#
#             JobSatPoints_9  JobSatPoints_10  JobSatPoints_11  \
# ResponseId
# 1                      NaN              NaN              NaN
# 2                      0.0              0.0              0.0
# 3                      NaN              NaN              NaN
# 4                      NaN              NaN              NaN
# 5                      NaN              NaN              NaN
#
#                      SurveyLength SurveyEase  ConvertedCompYearly  JobSat
# ResponseId
# 1                             NaN        NaN                  NaN     NaN
# 2                             NaN        NaN                  NaN     NaN
# 3           Appropriate in length       Easy                  NaN     NaN
# 4                        Too long       Easy                  NaN     NaN
# 5                       Too short       Easy                  NaN     NaN

# %%
sr_df.sort_values(by=['Country', 'CompTotal'], ascending=[False, False], inplace=True)

sr_df[['Country', 'CompTotal']]
# Out:
#                 Country  CompTotal
# ResponseId
# 2701           Zimbabwe    27000.0
# 1224           Zimbabwe     7200.0
# 1160           Zimbabwe        NaN
# 5984             Zambia    60000.0
# 4216             Zambia        NaN
# ...                 ...        ...
# 7690        Afghanistan        NaN
# 1328        Afghanistan        NaN
# 2138        Afghanistan        NaN
# 1378        Afghanistan        NaN
# 3823        Afghanistan        NaN
#
# [10000 rows x 2 columns]

# %%
sr_df['CompTotal'].nlargest(10)
# Out:
# ResponseId
# 8815    1.000000e+44
# 624     1.000000e+11
# 9733    5.000000e+10
# 7518    1.200000e+10
# 8632    1.000000e+10
# 8502    9.600000e+09
# 473     9.000000e+09
# 4649    8.000000e+09
# 3630    8.000000e+09
# 2922    7.000000e+09
# Name: CompTotal, dtype: float64

# %%
sr_df.nlargest(10, 'CompTotal')
# Out:
#                                                    MainBranch  \
# ResponseId
# 8815                           I am a developer by profession
# 624         I am not primarily a developer, but I write co...
# 9733        I am not primarily a developer, but I write co...
# 7518                           I am a developer by profession
# 8632                           I am a developer by profession
# 8502                           I am a developer by profession
# 473                            I am a developer by profession
# 4649                           I am a developer by profession
# 3630                           I am a developer by profession
# 2922                           I am a developer by profession
#
#                         Age  \
# ResponseId
# 8815        35-44 years old
# 624         35-44 years old
# 9733        55-64 years old
# 7518        25-34 years old
# 8632        25-34 years old
# 8502        25-34 years old
# 473         25-34 years old
# 4649        35-44 years old
# 3630        25-34 years old
# 2922        35-44 years old
#
#                                                    Employment  \
# ResponseId
# 8815                                      Employed, full-time
# 624                                       Employed, full-time
# 9733                                      Employed, part-time
# 7518        Employed, full-time;Independent contractor, fr...
# 8632                                      Employed, full-time
# 8502                                      Employed, full-time
# 473                                       Employed, full-time
# 4649                                      Employed, full-time
# 3630                                      Employed, full-time
# 2922                                      Employed, full-time
#
#                                       RemoteWork   Check  \
# ResponseId
# 8815        Hybrid (some remote, some in-person)  Apples
# 624         Hybrid (some remote, some in-person)  Apples
# 9733        Hybrid (some remote, some in-person)  Apples
# 7518                                      Remote  Apples
# 8632        Hybrid (some remote, some in-person)  Apples
# 8502        Hybrid (some remote, some in-person)  Apples
# 473                                    In-person  Apples
# 4649                                   In-person  Apples
# 3630                                   In-person  Apples
# 2922        Hybrid (some remote, some in-person)  Apples
#
#                                              CodingActivities  \
# ResponseId
# 8815        Hobby;Professional development or self-paced l...
# 624                                                     Hobby
# 9733        Contribute to open-source projects;Bootstrappi...
# 7518                           Hobby;Bootstrapping a business
# 8632                       Contribute to open-source projects
# 8502        Hobby;Contribute to open-source projects;Freel...
# 473                              I don’t code outside of work
# 4649                             I don’t code outside of work
# 3630        Contribute to open-source projects;Freelance/c...
# 2922                                  Freelance/contract work
#
#                                                       EdLevel  \
# ResponseId
# 8815           Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 624         Some college/university study without earning ...
# 9733          Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 7518        Some college/university study without earning ...
# 8632                      Associate degree (A.A., A.S., etc.)
# 8502          Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 473           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4649             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3630                      Associate degree (A.A., A.S., etc.)
# 2922          Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                                     LearnCode  \
# ResponseId
# 8815        Books / Physical media;Colleague;On the job tr...
# 624         Books / Physical media;Colleague;On the job tr...
# 9733        Books / Physical media;On the job training;Sch...
# 7518        Colleague;On the job training;Other online res...
# 8632        Books / Physical media;Other online resources ...
# 8502        Books / Physical media;On the job training;Onl...
# 473         On the job training;Other online resources (e....
# 4649        Books / Physical media;On the job training;Oth...
# 3630        Books / Physical media;On the job training;Oth...
# 2922        Colleague;On the job training;Other online res...
#
#                                               LearnCodeOnline  \
# ResponseId
# 8815        Technical documentation;Written Tutorials;How-...
# 624                                                       NaN
# 9733                                                      NaN
# 7518        Technical documentation;Blogs;Books;Written Tu...
# 8632        Technical documentation;Blogs;Written Tutorial...
# 8502                                                      NaN
# 473         Technical documentation;Written Tutorials;Stac...
# 4649        Technical documentation;Blogs;Books;Written Tu...
# 3630        Technical documentation;Blogs;Books;Written Tu...
# 2922        Technical documentation;Blogs;How-to videos;In...
#
#                                                       TechDoc YearsCode  \
# ResponseId
# 8815        API document(s) and/or SDK document(s);User gu...         7
# 624                                                       NaN        30
# 9733                                                      NaN        10
# 7518        API document(s) and/or SDK document(s);User gu...        10
# 8632                   API document(s) and/or SDK document(s)        12
# 8502                                                      NaN        12
# 473         API document(s) and/or SDK document(s);User gu...        12
# 4649        API document(s) and/or SDK document(s);User gu...        17
# 3630        API document(s) and/or SDK document(s);User gu...         8
# 2922        API document(s) and/or SDK document(s);User gu...         9
#
#            YearsCodePro                DevType                   OrgSize  \
# ResponseId
# 8815                 15    Developer, back-end  1,000 to 4,999 employees
# 624                  25   System administrator      500 to 999 employees
# 9733                  2    Academic researcher              I don’t know
# 7518                  6  Developer, full-stack          2 to 9 employees
# 8632                 12   Developer, front-end        10 to 19 employees
# 8502                  6  Developer, full-stack          2 to 9 employees
# 473                   9  Developer, full-stack        10 to 19 employees
# 4649                 11  Developer, full-stack        20 to 99 employees
# 3630                  4   Developer, front-end        10 to 19 employees
# 2922                  9      Developer, mobile        20 to 99 employees
#
#                            PurchaseInfluence  \
# ResponseId
# 8815                   I have some influence
# 624                    I have some influence
# 9733                   I have some influence
# 7518                   I have some influence
# 8632                   I have some influence
# 8502                   I have some influence
# 473            I have little or no influence
# 4649        I have a great deal of influence
# 3630                   I have some influence
# 2922                   I have some influence
#
#                                                    BuyNewTool  \
# ResponseId
# 8815                                  Other (please specify):
# 624         Ask developers I know/work with;Read ratings o...
# 9733                                       Start a free trial
# 7518        Start a free trial;Ask developers I know/work ...
# 8632        Start a free trial;Ask developers I know/work ...
# 8502        Start a free trial;Ask developers I know/work ...
# 473                                        Start a free trial
# 4649        Start a free trial;Ask developers I know/work ...
# 3630        Ask developers I know/work with;Visit develope...
# 2922        Start a free trial;Ask developers I know/work ...
#
#                                                    BuildvsBuy  \
# ResponseId
# 8815        Is ready-to-go but also customizable for growt...
# 624         Is ready-to-go but also customizable for growt...
# 9733        Is set up to be customized and needs to be eng...
# 7518        Is ready-to-go but also customizable for growt...
# 8632        Is set up to be customized and needs to be eng...
# 8502        Is ready-to-go but also customizable for growt...
# 473         Is ready-to-go but also customizable for growt...
# 4649        Is set up to be customized and needs to be eng...
# 3630        Is ready-to-go but also customizable for growt...
# 2922        Out-of-the-box is ready to go with little need...
#
#                                                   TechEndorse  \
# ResponseId
# 8815        APIs;Customization;Connected to an open source...
# 624                                 APIs;Customization;Other:
# 9733        APIs;Quality support system;Reputation for qua...
# 7518        APIs;Customization;Reputation for quality and ...
# 8632        APIs;Customization;Integrated developer commun...
# 8502          APIs;Customization;Frequent updates to features
# 473         APIs;Customization;Integrated developer commun...
# 4649        APIs;Customization;Integrated developer commun...
# 3630        APIs;Customization;Reputation for quality and ...
# 2922                                      AI tool integration
#
#                                  Country                         Currency  \
# ResponseId
# 8815                         Afghanistan  AED United Arab Emirates dirham
# 624                               Sweden               SEK\tSwedish krona
# 9733        Iran, Islamic Republic of...                IRR\tIranian rial
# 7518        Iran, Islamic Republic of...                IRR\tIranian rial
# 8632        Iran, Islamic Republic of...                IRR\tIranian rial
# 8502        Iran, Islamic Republic of...                IRR\tIranian rial
# 473         Iran, Islamic Republic of...                IRR\tIranian rial
# 4649        Iran, Islamic Republic of...                IRR\tIranian rial
# 3630        Iran, Islamic Republic of...                IRR\tIranian rial
# 2922        Iran, Islamic Republic of...                IRR\tIranian rial
#
#                CompTotal                             LanguageHaveWorkedWith  \
# ResponseId
# 8815        1.000000e+44                                                NaN
# 624         1.000000e+11                  Bash/Shell (all shells);Go;Python
# 9733        5.000000e+10                                 C++;MATLAB;PHP;SQL
# 7518        1.200000e+10  Bash/Shell (all shells);HTML/CSS;JavaScript;PH...
# 8632        1.000000e+10         HTML/CSS;JavaScript;Kotlin;Rust;TypeScript
# 8502        9.600000e+09  Bash/Shell (all shells);HTML/CSS;JavaScript;PH...
# 473         9.000000e+09         Go;HTML/CSS;Java;JavaScript;SQL;TypeScript
# 4649        8.000000e+09              C#;HTML/CSS;JavaScript;SQL;TypeScript
# 3630        8.000000e+09                     HTML/CSS;JavaScript;TypeScript
# 2922        7.000000e+09                                        Java;Kotlin
#
#                                        LanguageWantToWorkWith  \
# ResponseId
# 8815                                                      NaN
# 624                         Bash/Shell (all shells);Go;Python
# 9733                                                      NaN
# 7518        Bash/Shell (all shells);Go;HTML/CSS;JavaScript...
# 8632               HTML/CSS;JavaScript;Kotlin;Rust;TypeScript
# 8502        Bash/Shell (all shells);Go;HTML/CSS;JavaScript...
# 473         HTML/CSS;Java;JavaScript;Kotlin;SQL;Swift;Type...
# 4649                    C#;HTML/CSS;JavaScript;SQL;TypeScript
# 3630                           HTML/CSS;JavaScript;TypeScript
# 2922                                                      NaN
#
#                                               LanguageAdmired  \
# ResponseId
# 8815                                                      NaN
# 624                         Bash/Shell (all shells);Go;Python
# 9733                                                      NaN
# 7518        Bash/Shell (all shells);HTML/CSS;JavaScript;SQ...
# 8632               HTML/CSS;JavaScript;Kotlin;Rust;TypeScript
# 8502        Bash/Shell (all shells);HTML/CSS;JavaScript;PH...
# 473                   HTML/CSS;Java;JavaScript;SQL;TypeScript
# 4649                    C#;HTML/CSS;JavaScript;SQL;TypeScript
# 3630                           HTML/CSS;JavaScript;TypeScript
# 2922                                                      NaN
#
#                                        DatabaseHaveWorkedWith  \
# ResponseId
# 8815                                                      NaN
# 624                                                PostgreSQL
# 9733                                                    MySQL
# 7518            MariaDB;MongoDB;MySQL;PostgreSQL;Redis;SQLite
# 8632                            Cassandra;PostgreSQL;Supabase
# 8502        Firebase Realtime Database;MariaDB;MongoDB;MyS...
# 473                                                PostgreSQL
# 4649                               Microsoft SQL Server;Redis
# 3630                                                      NaN
# 2922                                                   SQLite
#
#                                        DatabaseWantToWorkWith  \
# ResponseId
# 8815                                                      NaN
# 624                                                PostgreSQL
# 9733                                                      NaN
# 7518                           MariaDB;MySQL;PostgreSQL;Redis
# 8632                                     Cassandra;PostgreSQL
# 8502        MariaDB;MongoDB;MySQL;PostgreSQL;Redis;SQLite;...
# 473                           Elasticsearch;PostgreSQL;SQLite
# 4649                               Microsoft SQL Server;Redis
# 3630                                                      NaN
# 2922                                                      NaN
#
#                                           DatabaseAdmired  \
# ResponseId
# 8815                                                  NaN
# 624                                            PostgreSQL
# 9733                                                  NaN
# 7518                       MariaDB;MySQL;PostgreSQL;Redis
# 8632                                 Cassandra;PostgreSQL
# 8502        MariaDB;MongoDB;MySQL;PostgreSQL;Redis;SQLite
# 473                                            PostgreSQL
# 4649                           Microsoft SQL Server;Redis
# 3630                                                  NaN
# 2922                                                  NaN
#
#                                       PlatformHaveWorkedWith  \
# ResponseId
# 8815                                                     NaN
# 624         Amazon Web Services (AWS);Managed Hosting;VMware
# 9733                                                     NaN
# 7518                               Amazon Web Services (AWS)
# 8632                           Digital Ocean;Supabase;Vercel
# 8502                       Cloudflare;Firebase;Heroku;Render
# 473                                                      NaN
# 4649                                                     NaN
# 3630                      Amazon Web Services (AWS);Firebase
# 2922                                            Google Cloud
#
#                           PlatformWantToWorkWith  \
# ResponseId
# 8815                                         NaN
# 624          Managed Hosting;OpenShift;OpenStack
# 9733                                         NaN
# 7518        Amazon Web Services (AWS);Cloudflare
# 8632                                      Vercel
# 8502         Cloudflare;Firebase;Render;Supabase
# 473                                          NaN
# 4649                                         NaN
# 3630          Amazon Web Services (AWS);Firebase
# 2922                                         NaN
#
#                                PlatformAdmired  \
# ResponseId
# 8815                                       NaN
# 624                            Managed Hosting
# 9733                                       NaN
# 7518                 Amazon Web Services (AWS)
# 8632                                    Vercel
# 8502                Cloudflare;Firebase;Render
# 473                                        NaN
# 4649                                       NaN
# 3630        Amazon Web Services (AWS);Firebase
# 2922                                       NaN
#
#                                        WebframeHaveWorkedWith  \
# ResponseId
# 8815                                                      NaN
# 624                                                    Vue.js
# 9733                                                   Svelte
# 7518                   NestJS;Next.js;Node.js;React;WordPress
# 8632                             NestJS;Next.js;Node.js;React
# 8502        Angular;Express;jQuery;NestJS;Next.js;Node.js;...
# 473                                         React;Spring Boot
# 4649                      Angular;ASP.NET;ASP.NET CORE;jQuery
# 3630                                            Next.js;React
# 2922                                 ASP.NET CORE;Spring Boot
#
#                                        WebframeWantToWorkWith  \
# ResponseId
# 8815                                                      NaN
# 624                                                    Vue.js
# 9733                                                WordPress
# 7518                                Htmx;NestJS;Node.js;React
# 8632                             NestJS;Next.js;Node.js;React
# 8502        Express;Gatsby;NestJS;Next.js;Node.js;React;Sy...
# 473                                             Next.js;React
# 4649                                     Angular;ASP.NET CORE
# 3630                                            Next.js;React
# 2922                                                      NaN
#
#                                          WebframeAdmired  \
# ResponseId
# 8815                                                 NaN
# 624                                               Vue.js
# 9733                                                 NaN
# 7518                                NestJS;Node.js;React
# 8632                        NestJS;Next.js;Node.js;React
# 8502        Express;NestJS;Next.js;Node.js;React;Symfony
# 473                                                React
# 4649                                Angular;ASP.NET CORE
# 3630                                       Next.js;React
# 2922                                                 NaN
#
#            EmbeddedHaveWorkedWith EmbeddedWantToWorkWith EmbeddedAdmired  \
# ResponseId
# 8815                          NaN                    NaN             NaN
# 624                           NaN                    NaN             NaN
# 9733                      Arduino            Rasberry Pi             NaN
# 7518                          NaN                    NaN             NaN
# 8632                        Cargo                  Cargo           Cargo
# 8502                          NaN                    NaN             NaN
# 473                           NaN                    NaN             NaN
# 4649                          NaN                    NaN             NaN
# 3630                          NaN                    NaN             NaN
# 2922                          NaN                    NaN             NaN
#
#                                     MiscTechHaveWorkedWith  \
# ResponseId
# 8815                                                   NaN
# 624                                                    NaN
# 9733                                                   NaN
# 7518                                              RabbitMQ
# 8632              Apache Kafka;Electron;React Native;Tauri
# 8502                                    Capacitor;Ionic;Qt
# 473                                           React Native
# 4649        .NET (5+) ;.NET Framework (1.0 - 4.8);RabbitMQ
# 3630                                                   NaN
# 2922                                                   NaN
#
#                                   MiscTechWantToWorkWith  \
# ResponseId
# 8815                                                 NaN
# 624                                                  NaN
# 9733                                                 NaN
# 7518                                            RabbitMQ
# 8632            Apache Kafka;Electron;React Native;Tauri
# 8502        Capacitor;Electron;Ionic;RabbitMQ;TensorFlow
# 473                                 Flutter;React Native
# 4649                                 .NET (5+) ;RabbitMQ
# 3630                                                 NaN
# 2922                                                 NaN
#
#                                      MiscTechAdmired  \
# ResponseId
# 8815                                             NaN
# 624                                              NaN
# 9733                                             NaN
# 7518                                        RabbitMQ
# 8632        Apache Kafka;Electron;React Native;Tauri
# 8502                                 Capacitor;Ionic
# 473                                     React Native
# 4649                             .NET (5+) ;RabbitMQ
# 3630                                             NaN
# 2922                                             NaN
#
#                                       ToolsTechHaveWorkedWith  \
# ResponseId
# 8815                                                      NaN
# 624                   Ansible;APT;Docker;Godot;Make;Terraform
# 9733                                   Visual Studio Solution
# 7518                                Docker;npm;pnpm;Vite;Yarn
# 8632                         Bun;Dagger;Docker;Kubernetes;npm
# 8502        Ansible;APT;Composer;Docker;Make;npm;Pip;pnpm;...
# 473                             Gradle;Maven (build tool);npm
# 4649                                                npm;NuGet
# 3630                                              npm;Webpack
# 2922                                                      NaN
#
#                                       ToolsTechWantToWorkWith  \
# ResponseId
# 8815                                                      NaN
# 624                   Ansible;APT;Docker;Godot;Make;Terraform
# 9733                                                      NaN
# 7518                                Docker;npm;pnpm;Vite;Yarn
# 8632                         Bun;Dagger;Docker;Kubernetes;npm
# 8502        Ansible;APT;Bun;Composer;Docker;Make;npm;Pip;p...
# 473         Chocolatey;Docker;Gradle;Maven (build tool);np...
# 4649                              Docker;Kubernetes;npm;NuGet
# 3630                                              npm;Webpack
# 2922                                                      NaN
#
#                                              ToolsTechAdmired  \
# ResponseId
# 8815                                                      NaN
# 624                   Ansible;APT;Docker;Godot;Make;Terraform
# 9733                                                      NaN
# 7518                                Docker;npm;pnpm;Vite;Yarn
# 8632                         Bun;Dagger;Docker;Kubernetes;npm
# 8502        Ansible;APT;Composer;Docker;Make;npm;Pip;pnpm;...
# 473                             Gradle;Maven (build tool);npm
# 4649                                                npm;NuGet
# 3630                                              npm;Webpack
# 2922                                                      NaN
#
#                                  NEWCollabToolsHaveWorkedWith  \
# ResponseId
# 8815                                                      NaN
# 624                                    Vim;Visual Studio Code
# 9733                         Rad Studio (Delphi, C++ Builder)
# 7518                                Neovim;Visual Studio Code
# 8632                                       Visual Studio Code
# 8502        Android Studio;IntelliJ IDEA;Nano;PhpStorm;PyC...
# 473           Android Studio;IntelliJ IDEA;Notepad++;WebStorm
# 4649                         Visual Studio;Visual Studio Code
# 3630                              Nano;Vim;Visual Studio Code
# 2922                   Android Studio;IntelliJ IDEA;Notepad++
#
#                                  NEWCollabToolsWantToWorkWith  \
# ResponseId
# 8815                                                      NaN
# 624                                    Vim;Visual Studio Code
# 9733                                                      NaN
# 7518                                       Visual Studio Code
# 8632                                       Visual Studio Code
# 8502        Android Studio;Goland;IntelliJ IDEA;Nano;PhpSt...
# 473         Android Studio;IntelliJ IDEA;Notepad++;WebStor...
# 4649                         Visual Studio;Visual Studio Code
# 3630                              Nano;Vim;Visual Studio Code
# 2922                                                      NaN
#
#                                         NEWCollabToolsAdmired  \
# ResponseId
# 8815                                                      NaN
# 624                                    Vim;Visual Studio Code
# 9733                                                      NaN
# 7518                                       Visual Studio Code
# 8632                                       Visual Studio Code
# 8502        Android Studio;IntelliJ IDEA;Nano;PhpStorm;PyC...
# 473           Android Studio;IntelliJ IDEA;Notepad++;WebStorm
# 4649                         Visual Studio;Visual Studio Code
# 3630                              Nano;Vim;Visual Studio Code
# 2922                                                      NaN
#
#                                             OpSysPersonal use  \
# ResponseId
# 8815                                  Other (please specify):
# 624                                            Ubuntu;Windows
# 9733                                       AIX;Red Hat;Ubuntu
# 7518                 Fedora;Windows Subsystem for Linux (WSL)
# 8632        Android;Debian;Ubuntu;Windows;Windows Subsyste...
# 8502                                         iOS;MacOS;Ubuntu
# 473                                           Android;Windows
# 4649                                                  Windows
# 3630                                                   Fedora
# 2922                                                  Windows
#
#                                         OpSysProfessional use  \
# ResponseId
# 8815                                  Other (please specify):
# 624                                                    Ubuntu
# 9733                                                  Windows
# 7518                        Windows Subsystem for Linux (WSL)
# 8632        Android;Debian;Ubuntu;Windows;Windows Subsyste...
# 8502                                             MacOS;Ubuntu
# 473                                 Android;iOS;MacOS;Windows
# 4649                                                  Windows
# 3630                                                   Fedora
# 2922                                                      NaN
#
#                                OfficeStackAsyncHaveWorkedWith  \
# ResponseId
# 8815                                                      NaN
# 624                       Confluence;Jira;Markdown File;Wikis
# 9733                                                      NaN
# 7518                                          Confluence;Jira
# 8632                                              Jira;Linear
# 8502        Airtable;Confluence;GitHub Discussions;Jira;Ma...
# 473                                                       NaN
# 4649                                             Azure Devops
# 3630                       Confluence;GitHub Discussions;Jira
# 2922                                  GitHub Discussions;Jira
#
#                                OfficeStackAsyncWantToWorkWith  \
# ResponseId
# 8815                                                      NaN
# 624                                       Markdown File;Wikis
# 9733                                                      NaN
# 7518                                          Confluence;Jira
# 8632                                                     Jira
# 8502        Airtable;Confluence;GitHub Discussions;Jira;Ma...
# 473                                                       NaN
# 4649                                             Azure Devops
# 3630                                       GitHub Discussions
# 2922                                                      NaN
#
#                                       OfficeStackAsyncAdmired  \
# ResponseId
# 8815                                                      NaN
# 624                                       Markdown File;Wikis
# 9733                                                      NaN
# 7518                                          Confluence;Jira
# 8632                                                     Jira
# 8502        Airtable;Confluence;GitHub Discussions;Jira;Ma...
# 473                                                       NaN
# 4649                                             Azure Devops
# 3630                                       GitHub Discussions
# 2922                                                      NaN
#
#                                 OfficeStackSyncHaveWorkedWith  \
# ResponseId
# 8815                                                      NaN
# 624                                    Matrix;Microsoft Teams
# 9733                      Cisco Webex Teams;Telegram;Whatsapp
# 7518                                        Google Meet;Slack
# 8632                                         Discord;Telegram
# 8502        Discord;Google Meet;Microsoft Teams;Skype;Slac...
# 473                                 Mattermost;Skype;Telegram
# 4649                                     Google Meet;Telegram
# 3630                             Discord;Google Meet;Telegram
# 2922                         Google Meet;Skype;Slack;Telegram
#
#                         OfficeStackSyncWantToWorkWith  \
# ResponseId
# 8815                                              NaN
# 624                                            Matrix
# 9733                                              NaN
# 7518                                Google Meet;Slack
# 8632                                 Discord;Telegram
# 8502        Google Meet;Microsoft Teams;Whatsapp;Zoom
# 473                                    Skype;Telegram
# 4649                             Google Meet;Telegram
# 3630                     Discord;Google Meet;Telegram
# 2922                                              NaN
#
#                                OfficeStackSyncAdmired  \
# ResponseId
# 8815                                              NaN
# 624                                            Matrix
# 9733                                              NaN
# 7518                                Google Meet;Slack
# 8632                                 Discord;Telegram
# 8502        Google Meet;Microsoft Teams;Whatsapp;Zoom
# 473                                    Skype;Telegram
# 4649                             Google Meet;Telegram
# 3630                     Discord;Google Meet;Telegram
# 2922                                              NaN
#
#                  AISearchDevHaveWorkedWith       AISearchDevWantToWorkWith  \
# ResponseId
# 8815                                   NaN                             NaN
# 624                                    NaN                             NaN
# 9733                         Google Gemini                             NaN
# 7518                       ChatGPT;Codeium                         Codeium
# 8632        Bing AI;ChatGPT;GitHub Copilot  Bing AI;ChatGPT;GitHub Copilot
# 8502                 ChatGPT;Google Gemini           ChatGPT;Google Gemini
# 473                                Bing AI                         Bing AI
# 4649                                   NaN                             NaN
# 3630                               ChatGPT                         ChatGPT
# 2922                 ChatGPT;Google Gemini                             NaN
#
#                         AISearchDevAdmired  \
# ResponseId
# 8815                                   NaN
# 624                                    NaN
# 9733                                   NaN
# 7518                               Codeium
# 8632        Bing AI;ChatGPT;GitHub Copilot
# 8502                 ChatGPT;Google Gemini
# 473                                Bing AI
# 4649                                   NaN
# 3630                               ChatGPT
# 2922                                   NaN
#
#                                                    NEWSOSites  \
# ResponseId
# 8815                                           Stack Overflow
# 624                             Stack Overflow;Stack Exchange
# 9733        Stack Overflow for Teams (private knowledge sh...
# 7518                                           Stack Overflow
# 8632                                           Stack Overflow
# 8502        Stack Overflow;Stack Exchange;Stack Overflow B...
# 473                             Stack Overflow;Stack Exchange
# 4649                            Stack Overflow;Stack Exchange
# 3630                            Stack Overflow;Stack Exchange
# 2922                                           Stack Overflow
#
#                                     SOVisitFreq                SOAccount  \
# ResponseId
# 8815        Less than once per month or monthly                      Yes
# 624                        A few times per week  Not sure/can't remember
# 9733        Less than once per month or monthly  Not sure/can't remember
# 7518                      Daily or almost daily                      Yes
# 8632                     Multiple times per day                      Yes
# 8502                     Multiple times per day                      Yes
# 473                      Multiple times per day                      Yes
# 4649                      Daily or almost daily                      Yes
# 3630                     Multiple times per day                      Yes
# 2922                      Daily or almost daily                      Yes
#
#                                      SOPartFreq  \
# ResponseId
# 8815        Less than once per month or monthly
# 624                                         NaN
# 9733                                        NaN
# 7518        Less than once per month or monthly
# 8632                       A few times per week
# 8502                       A few times per week
# 473             A few times per month or weekly
# 4649                       A few times per week
# 3630                     Multiple times per day
# 2922            A few times per month or weekly
#
#                                                         SOHow  \
# ResponseId
# 8815                           Quickly finding code solutions
# 624         Quickly finding code solutions;Learning new-to...
# 9733        Quickly finding code solutions;Finding reliabl...
# 7518        Quickly finding code solutions;Finding reliabl...
# 8632                           Quickly finding code solutions
# 8502        Quickly finding code solutions;Showcase expert...
# 473         Quickly finding code solutions;Finding reliabl...
# 4649        Quickly finding code solutions;Showcase expert...
# 3630        Quickly finding code solutions;Finding reliabl...
# 2922        Quickly finding code solutions;Finding reliabl...
#
#                      SOComm                 AISelect          AISent  \
# ResponseId
# 8815         No, not really  No, and I don't plan to             NaN
# 624          No, not at all  No, and I don't plan to             NaN
# 9733          Yes, somewhat                      Yes       Favorable
# 7518        Yes, definitely                      Yes  Very favorable
# 8632        Yes, definitely                      Yes  Very favorable
# 8502          Yes, somewhat                      Yes     Unfavorable
# 473         Yes, definitely                      Yes       Favorable
# 4649          Yes, somewhat   No, but I plan to soon     Indifferent
# 3630        Yes, definitely  No, and I don't plan to             NaN
# 2922          Yes, somewhat                      Yes  Very favorable
#
#                                                         AIBen  \
# ResponseId
# 8815                                                      NaN
# 624                                                       NaN
# 9733        Increase productivity;Improve collaboration;Sp...
# 7518        Increase productivity;Speed up learning;Improv...
# 8632        Increase productivity;Greater efficiency;Impro...
# 8502        Increase productivity;Greater efficiency;Speed...
# 473         Increase productivity;Greater efficiency;Speed...
# 4649                                                      NaN
# 3630                                                      NaN
# 2922        Increase productivity;Greater efficiency;Impro...
#
#                         AIAcc                                      AIComplex  \
# ResponseId
# 8815                      NaN                                            NaN
# 624                       NaN                                            NaN
# 9733           Somewhat trust  Good, but not great at handling complex tasks
# 7518        Somewhat distrust  Good, but not great at handling complex tasks
# 8632           Somewhat trust  Good, but not great at handling complex tasks
# 8502        Somewhat distrust            Very poor at handling complex tasks
# 473            Somewhat trust  Neither good or bad at handling complex tasks
# 4649                      NaN                                            NaN
# 3630                      NaN                                            NaN
# 2922           Somewhat trust  Good, but not great at handling complex tasks
#
#                                         AIToolCurrently Using  \
# ResponseId
# 8815                                                      NaN
# 624                                                       NaN
# 9733                                                      NaN
# 7518        Writing code;Documenting code;Debugging and ge...
# 8632        Learning about a codebase;Writing code;Debuggi...
# 8502        Writing code;Documenting code;Debugging and ge...
# 473         Writing code;Debugging and getting help;Search...
# 4649                                                      NaN
# 3630                                                      NaN
# 2922        Learning about a codebase;Writing code;Debuggi...
#
#                                     AIToolInterested in Using  \
# ResponseId
# 8815                                                      NaN
# 624                                                       NaN
# 9733        Learning about a codebase;Documenting code;Deb...
# 7518        Committing and reviewing code;Deployment and m...
# 8632        Project planning;Documenting code;Committing a...
# 8502        Learning about a codebase;Project planning;Tes...
# 473         Learning about a codebase;Documenting code;Tes...
# 4649                                                      NaN
# 3630                                                      NaN
# 2922        Project planning;Documenting code;Generating c...
#
#                          AIToolNot interested in Using  \
# ResponseId
# 8815                                               NaN
# 624                                                NaN
# 9733                                      Writing code
# 7518        Learning about a codebase;Project planning
# 8632                                               NaN
# 8502                                               NaN
# 473                                                NaN
# 4649                                               NaN
# 3630                                               NaN
# 2922                                               NaN
#
#                                    AINextMuch more integrated  \
# ResponseId
# 8815                                                      NaN
# 624                                                       NaN
# 9733                                                      NaN
# 7518        Writing code;Documenting code;Testing code;Gen...
# 8632                                                      NaN
# 8502        Documenting code;Committing and reviewing code...
# 473                                                       NaN
# 4649                                                      NaN
# 3630                                                      NaN
# 2922                                                      NaN
#
#                AINextNo change  \
# ResponseId
# 8815                       NaN
# 624                        NaN
# 9733                       NaN
# 7518                       NaN
# 8632                       NaN
# 8502        Search for answers
# 473                        NaN
# 4649                       NaN
# 3630                       NaN
# 2922                       NaN
#
#                                         AINextMore integrated  \
# ResponseId
# 8815                                                      NaN
# 624                                                       NaN
# 9733                                                      NaN
# 7518                               Debugging and getting help
# 8632                                                      NaN
# 8502                  Writing code;Debugging and getting help
# 473         Writing code;Debugging and getting help;Search...
# 4649                                                      NaN
# 3630                                                      NaN
# 2922        Learning about a codebase;Writing code;Debuggi...
#
#            AINextLess integrated AINextMuch less integrated      AIThreat  \
# ResponseId
# 8815                         NaN                        NaN           NaN
# 624                          NaN                        NaN           NaN
# 9733                         NaN                        NaN  I'm not sure
# 7518                         NaN                        NaN            No
# 8632                         NaN                        NaN            No
# 8502                         NaN                        NaN            No
# 473                          NaN                        NaN            No
# 4649                         NaN                        NaN  I'm not sure
# 3630                         NaN                        NaN           NaN
# 2922                         NaN                        NaN           Yes
#
#                                                      AIEthics  \
# ResponseId
# 8815                                                      NaN
# 624                                                       NaN
# 9733        Replacing jobs without options for new employm...
# 7518        Circulating misinformation or disinformation;M...
# 8632             Circulating misinformation or disinformation
# 8502        Circulating misinformation or disinformation;M...
# 473         Missing or incorrect attribution for sources o...
# 4649        Missing or incorrect attribution for sources o...
# 3630                                                      NaN
# 2922        Replacing jobs without options for new employm...
#
#                                                  AIChallenges TBranch  \
# ResponseId
# 8815                                                      NaN     Yes
# 624                                                       NaN      No
# 9733        Lack of proper training and education on new t...     NaN
# 7518        AI tools lack context of codebase,  internal a...     Yes
# 8632                                 Lack of executive buy-in     Yes
# 8502        AI tools lack context of codebase,  internal a...     Yes
# 473         Don’t trust the output or answers;Lack of prop...     Yes
# 4649                                                      NaN     Yes
# 3630                                                      NaN     Yes
# 2922        Don’t trust the output or answers;Lack of prop...      No
#
#                             ICorPM  WorkExp                 Knowledge_1  \
# ResponseId
# 8815        Individual contributor     35.0                         NaN
# 624                            NaN      NaN                         NaN
# 9733                           NaN      NaN                         NaN
# 7518        Individual contributor      7.0                    Disagree
# 8632        Individual contributor     10.0  Neither agree nor disagree
# 8502        Individual contributor     12.0              Strongly agree
# 473         Individual contributor      9.0              Strongly agree
# 4649        Individual contributor     13.0                       Agree
# 3630        Individual contributor      4.0                       Agree
# 2922                           NaN      NaN                         NaN
#
#                            Knowledge_2        Knowledge_3  \
# ResponseId
# 8815                               NaN                NaN
# 624                                NaN                NaN
# 9733                               NaN                NaN
# 7518                 Strongly disagree              Agree
# 8632        Neither agree nor disagree              Agree
# 8502                          Disagree     Strongly agree
# 473                     Strongly agree  Strongly disagree
# 4649        Neither agree nor disagree              Agree
# 3630        Neither agree nor disagree              Agree
# 2922                               NaN                NaN
#
#                            Knowledge_4                 Knowledge_5  \
# ResponseId
# 8815                               NaN                         NaN
# 624                                NaN                         NaN
# 9733                               NaN                         NaN
# 7518                             Agree              Strongly agree
# 8632                    Strongly agree              Strongly agree
# 8502        Neither agree nor disagree  Neither agree nor disagree
# 473         Neither agree nor disagree                       Agree
# 4649                             Agree                       Agree
# 3630                             Agree                       Agree
# 2922                               NaN                         NaN
#
#                            Knowledge_6                 Knowledge_7  \
# ResponseId
# 8815                               NaN                         NaN
# 624                                NaN                         NaN
# 9733                               NaN                         NaN
# 7518        Neither agree nor disagree                    Disagree
# 8632                             Agree              Strongly agree
# 8502                             Agree                       Agree
# 473                           Disagree                       Agree
# 4649        Neither agree nor disagree  Neither agree nor disagree
# 3630                          Disagree                    Disagree
# 2922                               NaN                         NaN
#
#                            Knowledge_8                 Knowledge_9  \
# ResponseId
# 8815                               NaN                         NaN
# 624                                NaN                         NaN
# 9733                               NaN                         NaN
# 7518        Neither agree nor disagree           Strongly disagree
# 8632                    Strongly agree              Strongly agree
# 8502                             Agree              Strongly agree
# 473                           Disagree                       Agree
# 4649        Neither agree nor disagree  Neither agree nor disagree
# 3630                             Agree                    Disagree
# 2922                               NaN                         NaN
#
#                  Frequency_1        Frequency_2        Frequency_3  \
# ResponseId
# 8815                   Never              Never              Never
# 624                      NaN                NaN                NaN
# 9733                     NaN                NaN                NaN
# 7518                   Never              Never   1-2 times a week
# 8632        3-5 times a week   3-5 times a week  6-10 times a week
# 8502        1-2 times a week   3-5 times a week              Never
# 473                    Never  6-10 times a week   3-5 times a week
# 4649        1-2 times a week   1-2 times a week   1-2 times a week
# 3630                   Never   10+ times a week   1-2 times a week
# 2922                     NaN                NaN                NaN
#
#                          TimeSearching               TimeAnswering  \
# ResponseId
# 8815            Over 120 minutes a day      Over 120 minutes a day
# 624                                NaN                         NaN
# 9733                               NaN                         NaN
# 7518               15-30 minutes a day         30-60 minutes a day
# 8632              60-120 minutes a day        60-120 minutes a day
# 8502              60-120 minutes a day         30-60 minutes a day
# 473               60-120 minutes a day        60-120 minutes a day
# 4649               15-30 minutes a day         15-30 minutes a day
# 3630        Less than 15 minutes a day  Less than 15 minutes a day
# 2922                               NaN                         NaN
#
#                                                   Frustration  \
# ResponseId
# 8815                                            None of these
# 624                                                       NaN
# 9733                                                      NaN
# 7518        Amount of technical debt;Tracking my work;Show...
# 8632                                            None of these
# 8502        Amount of technical debt;Number of software to...
# 473         Showing my contributions;Complexity of tech st...
# 4649        Amount of technical debt;Reliability of tools/...
# 3630                                            None of these
# 2922                                                      NaN
#
#                                              ProfessionalTech  \
# ResponseId
# 8815                                            None of these
# 624                                                       NaN
# 9733                                                      NaN
# 7518        DevOps function;Knowledge sharing community;Co...
# 8632                                            Microservices
# 8502        DevOps function;Knowledge sharing community;Co...
# 473         DevOps function;Automated testing;Observabilit...
# 4649                                   Innersource initiative
# 3630                                            None of these
# 2922                                                      NaN
#
#                              ProfessionalCloud  \
# ResponseId
# 8815                                   On-prem
# 624                                        NaN
# 9733                                       NaN
# 7518                Hybrid (on-prem and cloud)
# 8632                                   On-prem
# 8502        Cloud only (single or multi-cloud)
# 473                                    On-prem
# 4649                Hybrid (on-prem and cloud)
# 3630                                   On-prem
# 2922                                       NaN
#
#                                          ProfessionalQuestion  \
# ResponseId
# 8815                                                   Other:
# 624                                                       NaN
# 9733                                                      NaN
# 7518                                               A coworker
# 8632        Do search of internal share drives/storage loc...
# 8502                                               A coworker
# 473                                  AI-powered search (free)
# 4649                         Traditional public search engine
# 3630                                               A coworker
# 2922                                                      NaN
#
#                                               Industry  JobSatPoints_1  \
# ResponseId
# 8815                                            Other:             0.0
# 624                                                NaN             NaN
# 9733                                               NaN             NaN
# 7518                                           Fintech            95.0
# 8632                                           Fintech            20.0
# 8502                                     Manufacturing            80.0
# 473                               Software Development             0.0
# 4649                              Software Development            50.0
# 3630        Internet, Telecomm or Information Services            20.0
# 2922                                               NaN             NaN
#
#             JobSatPoints_4  JobSatPoints_5  JobSatPoints_6  JobSatPoints_7  \
# ResponseId
# 8815                   0.0             0.0             0.0             0.0
# 624                    NaN             NaN             NaN             NaN
# 9733                   NaN             NaN             NaN             NaN
# 7518                   0.0            66.0            88.0            77.0
# 8632                   0.0             0.0            20.0            20.0
# 8502                  20.0            50.0            80.0           100.0
# 473                    0.0             0.0             0.0             0.0
# 4649                   5.0            60.0            20.0            80.0
# 3630                  10.0             0.0             0.0            50.0
# 2922                   NaN             NaN             NaN             NaN
#
#             JobSatPoints_8  JobSatPoints_9  JobSatPoints_10  JobSatPoints_11  \
# ResponseId
# 8815                   0.0             0.0              0.0              0.0
# 624                    NaN             NaN              NaN              NaN
# 9733                   NaN             NaN              NaN              NaN
# 7518                  66.0            88.0             69.0             36.0
# 8632                   0.0             0.0              0.0             40.0
# 8502                  90.0            90.0             50.0             60.0
# 473                    0.0             0.0              0.0              0.0
# 4649                  60.0            50.0             40.0             40.0
# 3630                   0.0             0.0              0.0             20.0
# 2922                   NaN             NaN              NaN              NaN
#
#                      SurveyLength                  SurveyEase  \
# ResponseId
# 8815                    Too short                        Easy
# 624         Appropriate in length  Neither easy nor difficult
# 9733                     Too long  Neither easy nor difficult
# 7518                     Too long                        Easy
# 8632        Appropriate in length  Neither easy nor difficult
# 8502        Appropriate in length  Neither easy nor difficult
# 473                      Too long                        Easy
# 4649                     Too long  Neither easy nor difficult
# 3630        Appropriate in length                        Easy
# 2922                     Too long  Neither easy nor difficult
#
#             ConvertedCompYearly  JobSat
# ResponseId
# 8815                        NaN     5.0
# 624                         NaN     NaN
# 9733                  1188001.0     NaN
# 7518                   285120.0     8.0
# 8632                   237600.0     8.0
# 8502                   228096.0     7.0
# 473                    213840.0     4.0
# 4649                   190080.0     5.0
# 3630                   190080.0    10.0
# 2922                   166320.0     NaN
